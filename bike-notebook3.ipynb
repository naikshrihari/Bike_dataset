# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
import graphviz

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bike-sharing-demand/sampleSubmission.csv
# /kaggle/input/bike-sharing-demand/test.csv
# /kaggle/input/bike-sharing-demand/train.csv

# %%
train=pd.read_csv("../input/bike-sharing-demand/train.csv")
test=pd.read_csv("../input/bike-sharing-demand/test.csv")
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
full_data=train.append(test, sort=False)
full_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0     3.0        13.0   16.0
# 1        80        0.0     8.0        32.0   40.0
# 2        80        0.0     5.0        27.0   32.0
# 3        75        0.0     3.0        10.0   13.0
# 4        75        0.0     0.0         1.0    1.0

# %%
full_data["season"]=full_data.season.map({1:"spring", 2:"summer", 3:"fall", 4:"winter"})
full_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00  spring        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00  spring        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00  spring        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00  spring        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00  spring        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0     3.0        13.0   16.0
# 1        80        0.0     8.0        32.0   40.0
# 2        80        0.0     5.0        27.0   32.0
# 3        75        0.0     3.0        10.0   13.0
# 4        75        0.0     0.0         1.0    1.0

# %%
full_data["weather"]=full_data.weather.map({1: "Clear, Few clouds, Partly cloudy, Partly cloudy",
                                           2: "Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist",
                                           3: "Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds",
                                           4: "Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog "})

full_data.head()
# Out:
#               datetime  season  holiday  workingday  \
# 0  2011-01-01 00:00:00  spring        0           0
# 1  2011-01-01 01:00:00  spring        0           0
# 2  2011-01-01 02:00:00  spring        0           0
# 3  2011-01-01 03:00:00  spring        0           0
# 4  2011-01-01 04:00:00  spring        0           0
#
#                                            weather  temp   atemp  humidity  \
# 0  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        81
# 1  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 2  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 3  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
# 4  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
#
#    windspeed  casual  registered  count
# 0        0.0     3.0        13.0   16.0
# 1        0.0     8.0        32.0   40.0
# 2        0.0     5.0        27.0   32.0
# 3        0.0     3.0        10.0   13.0
# 4        0.0     0.0         1.0    1.0

# %%
full_data["datetime"]=pd.to_datetime(full_data["datetime"])
full_data["year"]=full_data["datetime"].dt.year
full_data["month"]=full_data["datetime"].dt.month
full_data["day"]=full_data["datetime"].dt.day
full_data["weekday"]=full_data["datetime"].dt.weekday
full_data.head()
# Out:
#              datetime  season  holiday  workingday  \
# 0 2011-01-01 00:00:00  spring        0           0
# 1 2011-01-01 01:00:00  spring        0           0
# 2 2011-01-01 02:00:00  spring        0           0
# 3 2011-01-01 03:00:00  spring        0           0
# 4 2011-01-01 04:00:00  spring        0           0
#
#                                            weather  temp   atemp  humidity  \
# 0  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        81
# 1  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 2  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 3  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
# 4  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
#
#    windspeed  casual  registered  count  year  month  day  weekday
# 0        0.0     3.0        13.0   16.0  2011      1    1        5
# 1        0.0     8.0        32.0   40.0  2011      1    1        5
# 2        0.0     5.0        27.0   32.0  2011      1    1        5
# 3        0.0     3.0        10.0   13.0  2011      1    1        5
# 4        0.0     0.0         1.0    1.0  2011      1    1        5

# %%
full_data.drop(["datetime"], axis=1, inplace=True)
full_data.head()
# Out:
#    season  holiday  workingday  \
# 0  spring        0           0
# 1  spring        0           0
# 2  spring        0           0
# 3  spring        0           0
# 4  spring        0           0
#
#                                            weather  temp   atemp  humidity  \
# 0  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        81
# 1  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 2  Clear, Few clouds, Partly cloudy, Partly cloudy  9.02  13.635        80
# 3  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
# 4  Clear, Few clouds, Partly cloudy, Partly cloudy  9.84  14.395        75
#
#    windspeed  casual  registered  count  year  month  day  weekday
# 0        0.0     3.0        13.0   16.0  2011      1    1        5
# 1        0.0     8.0        32.0   40.0  2011      1    1        5
# 2        0.0     5.0        27.0   32.0  2011      1    1        5
# 3        0.0     3.0        10.0   13.0  2011      1    1        5
# 4        0.0     0.0         1.0    1.0  2011      1    1        5

# %%
dum_full_data=pd.get_dummies(full_data, drop_first=True)
dum_full_data.tail()
# Out:
#       holiday  workingday   temp   atemp  humidity  windspeed  casual  \
# 6488        0           1  10.66  12.880        60    11.0014     NaN
# 6489        0           1  10.66  12.880        60    11.0014     NaN
# 6490        0           1  10.66  12.880        60    11.0014     NaN
# 6491        0           1  10.66  13.635        56     8.9981     NaN
# 6492        0           1  10.66  13.635        65     8.9981     NaN
#
#       registered  count  year  month  day  weekday  season_spring  \
# 6488         NaN    NaN  2012     12   31        0              1
# 6489         NaN    NaN  2012     12   31        0              1
# 6490         NaN    NaN  2012     12   31        0              1
# 6491         NaN    NaN  2012     12   31        0              1
# 6492         NaN    NaN  2012     12   31        0              1
#
#       season_summer  season_winter  \
# 6488              0              0
# 6489              0              0
# 6490              0              0
# 6491              0              0
# 6492              0              0
#
#       weather_Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog   \
# 6488                                                  0
# 6489                                                  0
# 6490                                                  0
# 6491                                                  0
# 6492                                                  0
#
#       weather_Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds  \
# 6488                                                  0
# 6489                                                  0
# 6490                                                  0
# 6491                                                  0
# 6492                                                  0
#
#       weather_Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 6488                                                  1
# 6489                                                  1
# 6490                                                  0
# 6491                                                  0
# 6492                                                  0

# %%
train.shape
# Out:
# (10886, 12)

# %%
X=dum_full_data.drop(["registered", "count", "casual"], axis=1)
y=dum_full_data["count"]
X.head()
# Out:
#    holiday  workingday  temp   atemp  humidity  windspeed  year  month  day  \
# 0        0           0  9.84  14.395        81        0.0  2011      1    1
# 1        0           0  9.02  13.635        80        0.0  2011      1    1
# 2        0           0  9.02  13.635        80        0.0  2011      1    1
# 3        0           0  9.84  14.395        75        0.0  2011      1    1
# 4        0           0  9.84  14.395        75        0.0  2011      1    1
#
#    weekday  season_spring  season_summer  season_winter  \
# 0        5              1              0              0
# 1        5              1              0              0
# 2        5              1              0              0
# 3        5              1              0              0
# 4        5              1              0              0
#
#    weather_Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog   \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    weather_Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    weather_Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0

# %%
y.head()
# Out:
# 0    16.0
# 1    40.0
# 2    32.0
# 3    13.0
# 4     1.0
# Name: count, dtype: float64

# %%
X_train=X.iloc[:10885,:]
X_test=X.iloc[10886:,:]
y_train=y.iloc[:10885]
y_test=y.iloc[10886:]
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((10885, 16), (10885,), (6493, 16), (6493,))

# %%
depth_range = [3,4,5,6,7,8,9]
minsplit_range = [5,10,20,25,30]
minleaf_range = [5,10,15]

# %%
parameters = dict(max_depth=depth_range,
                  min_samples_split=minsplit_range, 
                  min_samples_leaf=minleaf_range)

# %%
decTree=DecisionTreeRegressor(random_state=2018)
cv = GridSearchCV(decTree, param_grid=parameters, cv=5)
cv
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=2018,
#                                              splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [5, 10, 15],
#                          'min_samples_split': [5, 10, 20, 25, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=2018,
#                                              splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [5, 10, 15],
#                          'min_samples_split': [5, 10, 20, 25, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_pred=cv.predict(X_test)
y_pred
# Out:
# array([ 54.16504854,  54.16504854,  54.16504854, ..., 150.23300971,
#        150.23300971, 150.23300971])

# %%
sampleSubmission=pd.read_csv("../input/bike-sharing-demand/sampleSubmission.csv")
sampleSubmission.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
mysubmission=sampleSubmission.copy()
mysubmission["count"]=y_pred
mysubmission.head()
# Out:
#               datetime      count
# 0  2011-01-20 00:00:00  54.165049
# 1  2011-01-20 01:00:00  54.165049
# 2  2011-01-20 02:00:00  54.165049
# 3  2011-01-20 03:00:00  54.165049
# 4  2011-01-20 04:00:00  54.165049

# %%
mysubmission.to_csv("mysubmission.csv", index=False)
